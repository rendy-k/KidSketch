# %% [markdown]
# Guide to run this app using GPU from Colab or Kaggle

# %%
# Check if GPU is available
# !nvidia-smi

# %%
# Clone the repo
# !git clone https://github.com/rendy-k/KidCanvas
# Out:
# Cloning into 'KidCanvas'...
# remote: Enumerating objects: 34, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 34 (delta 10), reused 27 (delta 7), pack-reused 0
# Receiving objects: 100% (34/34), 879.04 KiB | 32.56 MiB/s, done.
# Resolving deltas: 100% (10/10), done.

# %%
import os
os.chdir('KidCanvas')
os.getcwd()
# Out:
# '/content/KidCanvas'

# %%
pip install -q -r requirements.txt
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 41.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 56.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 44.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.2/670.2 MB 1.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 80.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.4/309.4 kB 30.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 5.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.0/40.0 kB 4.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 22.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 86.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 9.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.8/209.8 MB 5.2 MB/s eta 0:00:00
# ...

# %%
# !npm install localtunnel
# Out:
# npm WARN saveError ENOENT: no such file or directory, open '/content/KidCanvas/package.json'
# npm WARN enoent ENOENT: no such file or directory, open '/content/KidCanvas/package.json'
# npm WARN KidCanvas No description
# npm WARN KidCanvas No repository field.
# npm WARN KidCanvas No README data
# npm WARN KidCanvas No license field.
#
# + localtunnel@2.0.2
# updated 1 package and audited 36 packages in 0.566s
#
# 3 packages are looking for funding
#   run `npm fund` for details
#
# found 2 moderate severity vulnerabilities
#   run `npm audit fix` to fix them, or `npm audit` for details

# %%
# !curl ipv4.icanhazip.com
# Copy the password
# Out:
# 34.150.225.142

# %%
# !streamlit run kidcanvas.py &>/content/logs.txt & npx localtunnel --port 8501
# Click the link and paste the password (the numbers generated from the above cell: !curl ipv4.icanhazip.com)
# Out:
# npx: installed 22 in 2.512s
# your url is: https://spotty-yaks-wink.loca.lt
# ^C
